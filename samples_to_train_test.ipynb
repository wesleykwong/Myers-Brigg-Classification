# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
# Ensures that tweet and user ids do not appear in scientific notation
pd.options.display.float_format = '{:.0f}'.format

# %%
german = pd.read_csv('DE-trial-text4.csv', index_col=0).dropna()
german = german.iloc[0:25000]
german['language'] = 'German'
german
# Out:
#        confirmed_tweet_ids    user_id  mbti  \
# 0       636404748460130304 2752637806  INFP
# 1       664796614247215104   10618562  ENFP
# 3       554472793921056768 1250360954  INFP
# 4       630742091245690880   19249012  ENFP
# 5        80730947657535488   37888929  ENTP
# ...                    ...        ...   ...
# 16520   463411339747409920  855190290  ENFP
# 16521   649977125165006848   63424385  INFJ
# 16522   544534462496010240   13172082  INTP
# 16523   578901794908213248 1244284644  ENFP
# 16524   608368150556602368   81117087  INFJ
#
#                                             twitter_text language
# 0      @NichtLaura 😩 Würde ich liebend gerne...glaub ...   German
# 1      @Gedankenmel Wenn ich wirklich sneaky sein wil...   German
# 3      @MissesVlog Hab zufällig im richtigen Momment ...   German
# 4      @dasYuuji Ich habe die Bestellung ein zweites ...   German
# 5      Jetzt muss auch noch das Abendkleid am Wochene...   German
# ...

# %%
spanish = pd.read_csv('ES-trial-text.csv', index_col=0).dropna()
spanish = spanish.iloc[0:25000]
spanish['language'] = 'Spanish'
spanish
# Out:
#        confirmed_tweet_ids   user_id  mbti  \
# 1       382700276576038912  91732481  ESTJ
# 2       433680598251487232 100252744  ISFJ
# 4       666067932791889920 458612984  ENTP
# 5       225207632875622400 194737197  INTJ
# 6       211997751037272064 100349273  INFP
# ...                    ...       ...   ...
# 11909   403977920214884416 190647090  INTJ
# 11910   474220960732966912  50753262  INTP
# 11911   223237406411866080  90379687  ESTJ
# 11912   156793718328922112  40788759  ISFJ
# 11914   108776795263877120  60480867  INFJ
#
#                                             twitter_text language
# 1      El marico cualquiera cree que es la persona qu...  Spanish
# 2      Una vaina es manifestar pacíficamente y otrs d...  Spanish
# 4      @SusanaStraus bueno todavía queda la adc de la...  Spanish
# 5      @kennygrullon #novoypaplaza hasta que arreglen...  Spanish
# 6             @osojimenez  tngo miedo!!  Y si me marcas?  Spanish
# ...

# %%
italian = pd.read_csv('IT-trial-text3.csv', index_col=0).dropna()
italian = italian.iloc[0:25000]
italian['language'] = 'Italian'
italian
# Out:
#       confirmed_tweet_ids    user_id  mbti  \
# 0      399583833026097216   70409384  INTP
# 1      693177077881794560 2973916630  INTJ
# 2      681396126080188416 1382370456  ENFP
# 3      509445790524116992  577327514  ISFP
# 5      669114591952117760 2222081301  INTP
# ...                   ...        ...   ...
# 3594   689409004632571904 1284380995  ENTJ
# 3595   649644471055949824  542772869  INTP
# 3596   627011781974728704  594743639  INTJ
# 3597   651096295264944128 1201405446  INFP
# 3599   546731988192071680 2806031165  ISTP
#
#                                            twitter_text language
# 0     non sono andata al lavoro per farli vincere #E...  Italian
# 1             ma se io lo volessi vedere, sto show.....  Italian
# 2     ground zeroes a 5 euro. e c'è gente che ne ha ...  Italian
# 3     10. amo il kpop, se vi piace seguire la massa ...  Italian
# 5     La bambina mi è simpatica, non parla e non rom...  Italian
# ...

# %%
dutch = pd.read_csv('NL-trial-text3.csv', index_col=0).dropna()
dutch = italian.iloc[0:25000]
dutch['language'] = 'Dutch'
dutch
# Out:
#       confirmed_tweet_ids    user_id  mbti  \
# 0      399583833026097216   70409384  INTP
# 1      693177077881794560 2973916630  INTJ
# 2      681396126080188416 1382370456  ENFP
# 3      509445790524116992  577327514  ISFP
# 5      669114591952117760 2222081301  INTP
# ...                   ...        ...   ...
# 3594   689409004632571904 1284380995  ENTJ
# 3595   649644471055949824  542772869  INTP
# 3596   627011781974728704  594743639  INTJ
# 3597   651096295264944128 1201405446  INFP
# 3599   546731988192071680 2806031165  ISTP
#
#                                            twitter_text language
# 0     non sono andata al lavoro per farli vincere #E...    Dutch
# 1             ma se io lo volessi vedere, sto show.....    Dutch
# 2     ground zeroes a 5 euro. e c'è gente che ne ha ...    Dutch
# 3     10. amo il kpop, se vi piace seguire la massa ...    Dutch
# 5     La bambina mi è simpatica, non parla e non rom...    Dutch
# ...

# %%
train_german, test_german = train_test_split(german, test_size=0.2, random_state=42)
train_spanish, test_spanish = train_test_split(spanish, test_size=0.2, random_state=42)
train_italian, test_italian = train_test_split(italian, test_size=0.2, random_state=42)
train_dutch, test_dutch = train_test_split(dutch, test_size=0.2, random_state=42)

# %%
train = pd.concat([train_german, train_spanish, train_italian, train_dutch])
train
# Out:
#        confirmed_tweet_ids    user_id  mbti  \
# 14222   559463518056222720   27621196  ISFJ
# 14668   473510634081239040  855190290  ENFP
# 889     377531414130229248  133708993  ENFJ
# 7705    578258496380149760  397366447  ENFP
# 1585    662601975658344448 1305617798  INTP
# ...                    ...        ...   ...
# 13586   680949466871009280  542772869  INTP
# 8513    635612601947394048  169452362  INFP
# 1371    466726191257636864   98672812  ENTJ
# 4695    561655376605872064  548470145  ESFJ
# 1551    585890144764461056   81557253  INFP
#
#                                             twitter_text language
# 14222  @alicedeee Ich könnte der stundenlang zuhören!...   German
# 14668  @Moaxi @KatrinaJulie kann ich immer noch sehen...   German
# 889    @GerhardMaier fand ich auch damals. Klappt das...   German
# 7705   38 qm für 700 warm ... ich muss verrückt sein ...   German
# 1585   @dilettiert Willkommen in unserer Welt. Liebe ...   German
# ...

# %%
test = pd.concat([test_german, test_spanish, test_italian, test_dutch])
test
# Out:
#        confirmed_tweet_ids    user_id  mbti  \
# 8856    158679079082659840   62117549  ENTP
# 15218   597014706436612096   17832573  ENFP
# 3635    134641950128214000   81568595  ENFP
# 1065    242712774025809920    3253641  ESTJ
# 1588    608464865997549568 3091403585  ISTP
# ...                    ...        ...   ...
# 13638   642030068894691328 1327151641  ENTP
# 18491   260711964781731840  548470145  ESFJ
# 6374    692631634366038016  201361241  INTJ
# 12934   671954187303919616  164412025  INFJ
# 1103    294216812768423936    8361022  ENTJ
#
#                                             twitter_text language
# 8856   Wisst ihr was das beste an #ibes ist? Dass sie...   German
# 15218  Ich hab Connis 7 Minuten letztes Jahr auch geh...   German
# 3635               @fat_jacK47 ja, aber ich wärs nich :D   German
# 1065                @Wally44 danke. Ist runtergeladen :)   German
# 1588                              @Patienti_A Schlaf gut   German
# ...

# %%
train.to_csv('twisty_train.csv')

# %%
test.to_csv('twisty_test.csv')
